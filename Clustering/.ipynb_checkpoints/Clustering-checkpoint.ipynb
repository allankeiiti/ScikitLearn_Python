# %% [markdown]
# # Clustering / Agrupamento - Aprendizagem não Supervisionada
# ##### Gera novos rótulos e aprende com a relação entre os dados<br>Elementos dentro de um grupo devem ser similares e diferentes dos que estão fora do grupo (nearest mean)
# ![image.png](attachment:image.png)
# #####
